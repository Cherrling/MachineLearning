# %%
import matplotlib.pyplot as plt
from sklearn import svm
import numpy as np

# %%
xx,yy = np.meshgrid(np.linspace(-3,3,500),np.linspace(-3,3,500))

np.random.seed(0)

X = np.random.randn(300,2)
Y = np.logical_xor(X[:,0]>0,X[:,1]>0)

clf = svm.SVC(kernel='rbf',gamma='auto')

clf.fit(X,Y)

Z = clf.decision_function(np.c_[xx.ravel(),yy.ravel()])
Z = Z.reshape(xx.shape)

plt.imshow(Z,interpolation='nearest',
              extent=(xx.min(),xx.max(),yy.min(),yy.max()),aspect='auto',
              origin='lower',cmap=plt.cm.PuOr_r)

contours = plt.contour(xx,yy,Z,levels=[0],linewidths=2,linetypes='dashed')

plt.scatter(X[:,0],X[:,1],s=30,c=Y,cmap=plt.cm.Paired,edgecolors='k')

plt.axis([-3,3,-3,3])
plt.show()
# Out:
# C:\Users\cherr\AppData\Local\Temp\ipykernel_15756\1868517760.py:19: UserWarning: The following kwargs were not used by contour: 'linetypes'
#   contours = plt.contour(xx,yy,Z,levels=[0],linewidths=2,linetypes='dashed')
