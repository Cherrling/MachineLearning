# %%
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
iris = load_iris()
features = iris.data
labels = iris.target

train_features,test_features,train_labels,test_labels = train_test_split(features,
                                                                         labels,
                                                                         test_size=0.2,
                                                                         random_state=0)


clf = DecisionTreeClassifier(criterion='gini')
clf = clf.fit(train_features,train_labels)

test_predict = clf.predict(test_features)

score = accuracy_score(test_labels,test_predict)
score2 = clf.score(test_features,test_labels)


print(f'test_predict:{test_predict}')
print("score:",score)
print("score2:",score2)

fig = plt.figure(figsize=(10,10))
tree.plot_tree (clf,feature_names=['sepal length ','sepal width ',
                                     'petal length ','petal width '],
                  class_names=['setosa','versicolor','virginica'])
fig.savefig("clf.png",bbox_inches='tight',dpi=fig.dpi,pad_inches=0.0)

plt.show()
# Out:
# test_predict:[2 1 0 2 0 2 0 1 1 1 2 1 1 1 1 0 1 1 0 0 2 1 0 0 2 0 0 1 1 0 2 1 0 2 2 1 0
#  2 1 1 2 0 2 0 0 1 2 2 1 2]
# score: 0.96
# score2: 0.96
